# %%
from pydantic import BaseModel, PositiveFloat
import numpy as np
import matplotlib.pyplot as plt

# %%
class Parametros(BaseModel):
    valor_central: float
    desviacion_estandar: PositiveFloat
    ruido: PositiveFloat
    n_datos: int

# %%
class ModeloJuguete:
    def __init__(self, parametros: Parametros):
        self.parametros = parametros

    def generar_datos(self) -> np.ndarray:
        datos = np.random.normal(loc=self.parametros.valor_central, scale=self.parametros.desviacion_estandar, size=self.parametros.n_datos)
        datos += np.random.normal(scale=self.parametros.ruido, size=self.parametros.n_datos)
        return datos

    def prediccion_teorica(self) -> float:
        return self.parametros.valor_central + self.parametros.desviacion_estandar * 2

# %%
parametros = Parametros(valor_central=10, desviacion_estandar=3, ruido=0.5, n_datos=50)
modelo = ModeloJuguete(parametros)

# %%
a = modelo.generar_datos()
f_a = [modelo.prediccion_teorica() for _ in range(parametros.n_datos)]
# O = ???

#errores = np.ones_like(O) * parametros.desviacion_estandar
#selim_ec = O + f_a / errores

#if np.all(costos < 1):
#    print("¡Condición cumplida!")
#else:
#    print("¡La condición no se cumple!")

# %%
plt.figure(figsize=(10, 6))
plt.hist(a, bins=30, color='blue', alpha=0.5, label='Datos Generados', density=True)
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.title('Datos Generados')
plt.legend()
plt.grid(True)
plt.show()
